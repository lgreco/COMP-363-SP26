# %% [markdown]
# # Assignment 04: Single-source shortest path
#
# ## Reading
#
# - [Chapter 8](https://jeffe.cs.illinois.edu/teaching/algorithms/book/08-sssp.pdf) from Jeff Erickson's book.
# - [Dijkstra's paper on SSPP](./dijkstra_sssp.pdf)
# - [An interview with E W Dijkstra](./acm_dijkstra.pdf)
# - [Recent research result improving SSSP](https://arxiv.org/pdf/2504.17033)

# %% [markdown]
# For this assignment we'll look at a _directed acyclic graph_ also known as a **dag.** The graph is abstracted like any other graph as a pair of a set of vertices and a set of edges: $G=(V,E)$. In an undirected graph,
#
# $$
# \forall u, v\in V: (u,v)\in E \Leftrightarrow (v,u)\in E
# $$
#
# In terms of the adjacency matrix $\mathbf G$,
#
# $$
# \mathbf G_{uv} = \mathbf G_{vu},\ \forall u,v\in V
# $$
#
# For a _dag,_ there is at least one pair of vertices such that
#
# $$
# \exists u, v \in V: (u,v)\in E\Leftrightarrow (v,u)\not\in E
# $$
#
# Otherwise, the representation of a _dag_ is the same as the representation of an undirected graph. The only difference is that in an undirected graph it is sufficient to explore about about half the adjacency matrix because of its symmetry. In the dag, we must explore every value in the matrix (except the main diagonal).
#
# In the Single-Source Shortest Path (SSSP) problem, we are given a dag $G=(V,E)$ and a source vertex $s\in V$, and we must find the shortest distances $d(u)$ from $s$ to every vertex $u\in V$.

# %% [markdown]
# Let's try it on a simple graph, using vertex 0 as source. The figure below shows the shortest paths, to illustrate the concept.

# %% [markdown]
# ![](https://raw.githubusercontent.com/lgreco/images/refs/heads/main/graphs/dag_sssp.png)

# %% [markdown]
# As we discussed in class, the distances can be computed as follows.

# %% [markdown]
# ----
# ### Codebase

# %%
# fmt: off

def sssp(s, G):
    n: int = len(G)                         # Shortcut to size of graph
    no_edge = G[0][0]                       # Shortcut to absence of edge
    oo = float("inf")                       # Shortcut to infinity
    d: list = [oo for _ in range(n)]        # Assume looooong distances
    d[s] = 0                                # Source distance to itself
    bag = [s]                               # Start from source
    while len(bag) > 0:                     # While bag not empty
        u = bag.pop()                       # Take a vertex out of bag
        for v in range(n):                  # Find u's neighbors
            if G[u][v] != no_edge:          # There is an edge (u,v)
                if d[v] > d[u] + G[u][v]:   # Is edge (u,v) tense?
                    d[v] = d[u] + G[u][v]   # Relax the edge
                    bag.append(v)           # Explore v next
    return d                                # Shortest path distances

# fmt: off
graph = [
    #0   1   2   3   4   5   6   7
    [0,  5,  1,  5, 10,  0,  0,  0],  # 0
    [0,  0, 12,  5,  6,  0,  0,  0],  # 1
    [0,  0,  0,  1,  0,  0,  5,  0],  # 2
    [0,  0,  0,  0,  0,  1,  5,  0],  # 3
    [0,  0,  0,  6,  0,  5,  0,  5],  # 4
    [0,  0,  0,  0,  0,  0,  1,  5],  # 5
    [0,  0,  0,  0,  0,  0,  0,  1],  # 6
    [0,  0,  0,  0,  0,  0,  0,  0],  # 7
]

# %% [markdown]
# ---
#
# The code above is far from perfect but it works as long as there are no cycles in the graph.

# %%
print(sssp(0,graph))
# Out:
# [0, 5, 1, 2, 10, 3, 4, 5]

# %% [markdown]
# ### Part 1: reconstruct the shortest paths
#
# The code above produces a list `d` with the shortest path distances from a source vertex $s$ to any vertex in the graph.
#
# Write a method with the following header
#
# ```python
# reconstruct(d: list[int], s: int, graph: list[list[int]]) -> list[int]
# ```
#
# that returns a list of `p` such that `p[u]` is the predecessor of `u` in the shortedt path from the source vertex (`s`) to `u`. For the source vertex we accept `p[s]=None`. Using the earlier graph as an example, we'll have the following values:
#
# ```python
#     p[0]: None
#     p[1]: 0
#     p[2]: 0
#     p[3]: 2
#     p[4]: 0
#     p[5]: 3
#     p[6]: 5
#     p[7]: 6
# ```
#
# *Hint:* an edge $u\rightarrow v$ is in the shortest path from $s$ to $v$ if $d(v) = d(u)+\mathbf G_{uv}$.
#
# Your best coding skills should shine through this method.

# %% [markdown]
# ### Part 2: report about the shortest paths
#
# Write a method with header
#
# ```python
# report_sssp(p: list[int], d: list[int], graph: list[list[int]]) -> None
# ```
#
# that prints the shortest path to every vertex in the graph, from the source vertex. For example, the shortest path to vertex 7 is `0 -> 2 -> 3 -> 5 -> 6 -> 7`
#
# Your best coding skills should shine through this method as well.

# %% [markdown]
# ### Part 3: Ungrading
#
# Review your solutions for the first three assignemnts. Compare your work with the posted solutions ([here](../week01/solution.ipynb) for week 1, [here](../week02/solutions.ipynb) for week 2, and [here](../week03/solutions.ipynb) for week 3).
#
# There is no point value attached to this exercise. Instead, you are being asked to do something more important: analyze your own thinking.
#
# For each of the three homework assignments, do the following:
#
# * Compare your solution to the posted solution
# * Focus on approach, structure, and reasoning, not just the final answer.
# * If your solution differs but is still correct, say so and explain why.
# * Identify mistakes or weaknesses; these may include:
#   * Logical errors
#   * Incorrect assumptions
#   * Gaps in justification
#   * Inefficient or unclear reasoning
#   * A correct idea that was poorly communicated
#   * If you made no mistakes, explain what made your solution solid.
#
# * Explain what you learned
#   * What concept became clearer?
#   * Algorithm design technique?
#   * What would you do differently if you saw a similar problem again?
#
# * What not to do
#   * Do not simply list differences.
#   * Do not write “I understand it now” without explaining what changed.
#   * Do not write what you think I want to hear.
#   * This is not about apologizing, defending yourself, or re-solving the problem.
#   * Honest analysis is more valuable than perfection.
#
# **Length and format:** About 100-200 words per assignment. Plain text or PDF is fine. Use clear headings like: *Homework 1 Reflection, Homework 2 Reflection, ...*
#
# **How this is assessed:**  Thoughtful, specific reflections signal engagement and growth. Superficial or perfunctory reflections signal the opposite. Your reflections will be taken into account  when determining your course grade.
#
# **Final note:** Strong students are not the ones who never make mistakes. They are the ones who recognize patterns in their mistakes and correct them early. This exercise is practice in doing exactly that.

# %% [markdown]
# ### What to submit
#
# A file `week04.py` with your code, **including the codebase from above,** uploaded on Sakai.
#
# If your ungrading is in plain text, you may add it to the end of your `week04.py` file as a *docstring* block. If your ungrading is formatted text, you may upload a PDF file on Sakai as well.
